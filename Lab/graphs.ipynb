# %%
import main
x=main.n_values
y=main.n_values1
global_min = min(min(main.times_quick_three), min(main.times_quick_random), min(main.times_counting), min(main.times_radix))
global_max = max(max(main.times_quick_three), max(main.times_quick_random), max(main.times_counting), max(main.times_radix))
# Out:
# Tmin = 0.00030030 s
# n =    100 | Random: 0.00009050 s | Median-of-Medians: 0.00011455 s | Three-way: 0.00008172 s | Counting: 0.04406425 s | RDX: 0.00010468 s
# n =    107 | Random: 0.00010629 s | Median-of-Medians: 0.00012453 s | Three-way: 0.00010210 s | Counting: 0.04419966 s | RDX: 0.00011473 s
# n =    114 | Random: 0.00010692 s | Median-of-Medians: 0.00012474 s | Three-way: 0.00009385 s | Counting: 0.04343449 s | RDX: 0.00010869 s
# n =    123 | Random: 0.00011618 s | Median-of-Medians: 0.00014380 s | Three-way: 0.00010753 s | Counting: 0.04392345 s | RDX: 0.00012564 s
# n =    132 | Random: 0.00012838 s | Median-of-Medians: 0.00015514 s | Three-way: 0.00011200 s | Counting: 0.04309235 s | RDX: 0.00012442 s
# n =    141 | Random: 0.00012916 s | Median-of-Medians: 0.00018331 s | Three-way: 0.00012026 s | Counting: 0.04414328 s | RDX: 0.00013160 s
# n =    151 | Random: 0.00014621 s | Median-of-Medians: 0.00020552 s | Three-way: 0.00013144 s | Counting: 0.04421660 s | RDX: 0.00015384 s
# n =    162 | Random: 0.00016204 s | Median-of-Medians: 0.00019386 s | Three-way: 0.00015118 s | Counting: 0.04355237 s | RDX: 0.00018755 s
# n =    174 | Random: 0.00017821 s | Median-of-Medians: 0.00021767 s | Three-way: 0.00016352 s | Counting: 0.04511964 s | RDX: 0.00016305 s
# n =    187 | Random: 0.00018020 s | Median-of-Medians: 0.00023724 s | Three-way: 0.00017215 s | Counting: 0.04434378 s | RDX: 0.00017676 s
# n =    200 | Random: 0.00019501 s | Median-of-Medians: 0.00024220 s | Three-way: 0.00018222 s | Counting: 0.04433377 s | RDX: 0.00019266 s
# n =    215 | Random: 0.00021903 s | Median-of-Medians: 0.00025825 s | Three-way: 0.00020194 s | Counting: 0.04463491 s | RDX: 0.00019871 s
# n =    231 | Random: 0.00022032 s | Median-of-Medians: 0.00029517 s | Three-way: 0.00021568 s | Counting: 0.04421822 s | RDX: 0.00022118 s
# n =    247 | Random: 0.00025209 s | Median-of-Medians: 0.00031753 s | Three-way: 0.00023811 s | Counting: 0.04348566 s | RDX: 0.00022579 s
# n =    265 | Random: 0.00029375 s | Median-of-Medians: 0.00033248 s | Three-way: 0.00028062 s | Counting: 0.04486934 s | RDX: 0.00026456 s
# n =    284 | Random: 0.00028498 s | Median-of-Medians: 0.00039035 s | Three-way: 0.00027254 s | Counting: 0.04494570 s | RDX: 0.00026999 s
# n =    305 | Random: 0.00031513 s | Median-of-Medians: 0.00043014 s | Three-way: 0.00029849 s | Counting: 0.04553400 s | RDX: 0.00030732 s
# n =    327 | Random: 0.00034552 s | Median-of-Medians: 0.00043613 s | Three-way: 0.00031689 s | Counting: 0.04791261 s | RDX: 0.00030999 s
# n =    351 | Random: 0.00037087 s | Median-of-Medians: 0.00046954 s | Three-way: 0.00035975 s | Counting: 0.04772517 s | RDX: 0.00037999 s
# n = 100000 | Random: 0.18602815 s | Median-of-Medians: 0.24969967 s | Three-way: 0.20511402 s | Counting: 0.09486295 s | RDX: 0.12427297 s
# End 1st
# n =    100 | Random: 0.01532408 s | Median-of-Medians: 0.02316730 s | Three-way: 0.01562420 s | Counting: 0.06193920 s | RDX: 0.01035040 s
# n =    104 | Random: 0.01588459 s | Median-of-Medians: 0.02315870 s | Three-way: 0.01696040 s | Counting: 0.05967080 s | RDX: 0.01104760 s
# n =    109 | Random: 0.01528793 s | Median-of-Medians: 0.02310800 s | Three-way: 0.01742460 s | Counting: 0.06430310 s | RDX: 0.01163320 s
# n =    114 | Random: 0.01638708 s | Median-of-Medians: 0.02285690 s | Three-way: 0.01567200 s | Counting: 0.06012670 s | RDX: 0.01107600 s
# n =    120 | Random: 0.01562291 s | Median-of-Medians: 0.02336550 s | Three-way: 0.01564700 s | Counting: 0.06107400 s | RDX: 0.01056060 s
# n =    126 | Random: 0.01566040 s | Median-of-Medians: 0.02318830 s | Three-way: 0.01564480 s | Counting: 0.06001250 s | RDX: 0.01053110 s
# n =    132 | Random: 0.01578332 s | Median-of-Medians: 0.02207460 s | Three-way: 0.01570960 s | Counting: 0.05854220 s | RDX: 0.01064220 s
# n =    138 | Random: 0.01603332 s | Median-of-Medians: 0.02389060 s | Three-way: 0.01611490 s | Counting: 0.05856700 s | RDX: 0.01116270 s
# n =    145 | Random: 0.01578935 s | Median-of-Medians: 0.02521610 s | Three-way: 0.01551920 s | Counting: 0.05952380 s | RDX: 0.01085000 s
# n =    151 | Random: 0.01535634 s | Median-of-Medians: 0.02528390 s | Three-way: 0.01662500 s | Counting: 0.05837920 s | RDX: 0.01069260 s
# n =    159 | Random: 0.01537042 s | Median-of-Medians: 0.02578150 s | Three-way: 0.01550930 s | Counting: 0.05931700 s | RDX: 0.01094200 s
# n =    166 | Random: 0.01541469 s | Median-of-Medians: 0.02437800 s | Three-way: 0.01612480 s | Counting: 0.06133390 s | RDX: 0.01030270 s
# n =    174 | Random: 0.01635621 s | Median-of-Medians: 0.02543320 s | Three-way: 0.01622300 s | Counting: 0.06151380 s | RDX: 0.01077390 s
# n =    183 | Random: 0.01625710 s | Median-of-Medians: 0.02596570 s | Three-way: 0.01605960 s | Counting: 0.06219860 s | RDX: 0.01194620 s
# n =    191 | Random: 0.01605345 s | Median-of-Medians: 0.02572350 s | Three-way: 0.01617610 s | Counting: 0.06017240 s | RDX: 0.01051000 s
# n =    200 | Random: 0.01583392 s | Median-of-Medians: 0.02702690 s | Three-way: 0.01536510 s | Counting: 0.06047080 s | RDX: 0.01026460 s
# n =    210 | Random: 0.01626441 s | Median-of-Medians: 0.02805500 s | Three-way: 0.01604280 s | Counting: 0.06125510 s | RDX: 0.01052430 s
# n =    220 | Random: 0.01607552 s | Median-of-Medians: 0.02712740 s | Three-way: 0.01644190 s | Counting: 0.06314350 s | RDX: 0.01096770 s
# n =    231 | Random: 0.01653719 s | Median-of-Medians: 0.02624180 s | Three-way: 0.01671400 s | Counting: 0.06147920 s | RDX: 0.01088110 s
# n =    242 | Random: 0.01660398 s | Median-of-Medians: 0.02967620 s | Three-way: 0.01635670 s | Counting: 0.06047300 s | RDX: 0.01067750 s
# n =    253 | Random: 0.01638148 s | Median-of-Medians: 0.02715030 s | Three-way: 0.01583370 s | Counting: 0.06149870 s | RDX: 0.01082280 s
# n =    265 | Random: 0.01656899 s | Median-of-Medians: 0.02757330 s | Three-way: 0.01620430 s | Counting: 0.06046110 s | RDX: 0.01118150 s
# n =    278 | Random: 0.01758678 s | Median-of-Medians: 0.03201290 s | Three-way: 0.01659980 s | Counting: 0.06068920 s | RDX: 0.01175590 s
# n =    291 | Random: 0.01603660 s | Median-of-Medians: 0.03051030 s | Three-way: 0.01667070 s | Counting: 0.06133950 s | RDX: 0.01078600 s
# n =    305 | Random: 0.01633071 s | Median-of-Medians: 0.02762190 s | Three-way: 0.01675150 s | Counting: 0.06017870 s | RDX: 0.01044870 s
# n =    319 | Random: 0.01629900 s | Median-of-Medians: 0.03413770 s | Three-way: 0.01638490 s | Counting: 0.05934040 s | RDX: 0.01048660 s
# n =    335 | Random: 0.01618704 s | Median-of-Medians: 0.03834700 s | Three-way: 0.01546650 s | Counting: 0.06060760 s | RDX: 0.01090140 s
# n =    351 | Random: 0.01645460 s | Median-of-Medians: 0.03568040 s | Three-way: 0.01537600 s | Counting: 0.06257420 s | RDX: 0.01111630 s
# n =    367 | Random: 0.01664203 s | Median-of-Medians: 0.03825230 s | Three-way: 0.01578430 s | Counting: 0.05891360 s | RDX: 0.01075960 s
# n =    385 | Random: 0.01721638 s | Median-of-Medians: 0.04660160 s | Three-way: 0.01530910 s | Counting: 0.05927280 s | RDX: 0.01035910 s
# n =    403 | Random: 0.01668058 s | Median-of-Medians: 0.03454730 s | Three-way: 0.01593170 s | Counting: 0.06092550 s | RDX: 0.01066190 s
# n =    422 | Random: 0.01768126 s | Median-of-Medians: 0.04044920 s | Three-way: 0.01609570 s | Counting: 0.05934090 s | RDX: 0.01118400 s
# n =    443 | Random: 0.01692553 s | Median-of-Medians: 0.03688200 s | Three-way: 0.01628710 s | Counting: 0.05904140 s | RDX: 0.01352300 s
# n =    464 | Random: 0.01759346 s | Median-of-Medians: 0.03939520 s | Three-way: 0.01698270 s | Counting: 0.06222510 s | RDX: 0.01061090 s
# n =    486 | Random: 0.01728897 s | Median-of-Medians: 0.05378890 s | Three-way: 0.01515410 s | Counting: 0.05978790 s | RDX: 0.01028800 s
# n =    509 | Random: 0.01812645 s | Median-of-Medians: 0.06340680 s | Three-way: 0.01673460 s | Counting: 0.05848830 s | RDX: 0.01237700 s
# n =    533 | Random: 0.01775073 s | Median-of-Medians: 0.05467230 s | Three-way: 0.01518600 s | Counting: 0.06114850 s | RDX: 0.00989940 s
# n =    559 | Random: 0.01914875 s | Median-of-Medians: 0.04821960 s | Three-way: 0.01473690 s | Counting: 0.06205320 s | RDX: 0.01051110 s
# n =    585 | Random: 0.01944948 s | Median-of-Medians: 0.06208900 s | Three-way: 0.01608440 s | Counting: 0.05771120 s | RDX: 0.01094330 s
# n =    613 | Random: 0.01915397 s | Median-of-Medians: 0.07045700 s | Three-way: 0.01509220 s | Counting: 0.05925210 s | RDX: 0.01023090 s
# n =    642 | Random: 0.01961079 s | Median-of-Medians: 0.05518390 s | Three-way: 0.01439210 s | Counting: 0.05853060 s | RDX: 0.01087330 s
# n =    673 | Random: 0.02025637 s | Median-of-Medians: 0.05768930 s | Three-way: 0.01414690 s | Counting: 0.06139230 s | RDX: 0.01090660 s
# n =    705 | Random: 0.02004287 s | Median-of-Medians: 0.08736580 s | Three-way: 0.01604960 s | Counting: 0.06221210 s | RDX: 0.01046730 s
# n =    739 | Random: 0.02011605 s | Median-of-Medians: 0.08553290 s | Three-way: 0.01525420 s | Counting: 0.05855040 s | RDX: 0.01049090 s
# n =    774 | Random: 0.02130295 s | Median-of-Medians: 0.08038830 s | Three-way: 0.01513770 s | Counting: 0.05885720 s | RDX: 0.01111870 s
# n =    811 | Random: 0.02161498 s | Median-of-Medians: 0.08890320 s | Three-way: 0.01431990 s | Counting: 0.06039650 s | RDX: 0.01075740 s
# n =    849 | Random: 0.02250446 s | Median-of-Medians: 0.09099420 s | Three-way: 0.01365460 s | Counting: 0.06049820 s | RDX: 0.01108670 s
# n =    890 | Random: 0.02268915 s | Median-of-Medians: 0.08304700 s | Three-way: 0.01424760 s | Counting: 0.06009280 s | RDX: 0.01087890 s
# n =    932 | Random: 0.02342455 s | Median-of-Medians: 0.12014860 s | Three-way: 0.01510310 s | Counting: 0.05937770 s | RDX: 0.01074060 s
# n =    977 | Random: 0.02426623 s | Median-of-Medians: 0.15780620 s | Three-way: 0.01421670 s | Counting: 0.05922260 s | RDX: 0.01116080 s
# n =   1023 | Random: 0.02590436 s | Median-of-Medians: 0.18990780 s | Three-way: 0.01444890 s | Counting: 0.06081070 s | RDX: 0.01033560 s
# n =   1072 | Random: 0.02643340 s | Median-of-Medians: 0.15453930 s | Three-way: 0.01544140 s | Counting: 0.06050510 s | RDX: 0.01109650 s
# n =   1123 | Random: 0.02758543 s | Median-of-Medians: 0.16545940 s | Three-way: 0.01535410 s | Counting: 0.05925240 s | RDX: 0.01090640 s
# n =   1176 | Random: 0.02822872 s | Median-of-Medians: 0.18665680 s | Three-way: 0.01410000 s | Counting: 0.05980370 s | RDX: 0.01113460 s
# n =   1232 | Random: 0.02994400 s | Median-of-Medians: 0.13794640 s | Three-way: 0.01448630 s | Counting: 0.06010540 s | RDX: 0.01099970 s
# n =   1291 | Random: 0.03161706 s | Median-of-Medians: 0.20724400 s | Three-way: 0.01420490 s | Counting: 0.05856890 s | RDX: 0.01142210 s
# n =   1353 | Random: 0.03317667 s | Median-of-Medians: 0.27027480 s | Three-way: 0.01582080 s | Counting: 0.05901470 s | RDX: 0.01105140 s
# n =   1417 | Random: 0.03366802 s | Median-of-Medians: 0.21788160 s | Three-way: 0.01434440 s | Counting: 0.06235630 s | RDX: 0.01097130 s
# n =   1484 | Random: 0.03635882 s | Median-of-Medians: 0.20850520 s | Three-way: 0.01462010 s | Counting: 0.05928710 s | RDX: 0.01069770 s
# n =   1555 | Random: 0.03763878 s | Median-of-Medians: 0.32947510 s | Three-way: 0.01328850 s | Counting: 0.05738140 s | RDX: 0.01143040 s
# n =   1629 | Random: 0.04043796 s | Median-of-Medians: 0.22490910 s | Three-way: 0.01484930 s | Counting: 0.05829000 s | RDX: 0.01076100 s
# n =   1707 | Random: 0.04271975 s | Median-of-Medians: 0.32738580 s | Three-way: 0.01237250 s | Counting: 0.05970090 s | RDX: 0.01113600 s
# n =   1788 | Random: 0.04470454 s | Median-of-Medians: 0.50816960 s | Three-way: 0.01389120 s | Counting: 0.05809770 s | RDX: 0.01062060 s
# n =   1873 | Random: 0.04662571 s | Median-of-Medians: 0.25886710 s | Three-way: 0.01425600 s | Counting: 0.06123550 s | RDX: 0.01044420 s
# n =   1963 | Random: 0.05021590 s | Median-of-Medians: 0.37582310 s | Three-way: 0.01304510 s | Counting: 0.05858150 s | RDX: 0.01059830 s
# n =   2056 | Random: 0.05488507 s | Median-of-Medians: 0.59163900 s | Three-way: 0.01304490 s | Counting: 0.05841810 s | RDX: 0.01038600 s
# n =   2154 | Random: 0.05814132 s | Median-of-Medians: 0.61340730 s | Three-way: 0.01277740 s | Counting: 0.05789260 s | RDX: 0.01156010 s
# n =   2257 | Random: 0.06337474 s | Median-of-Medians: 0.48957950 s | Three-way: 0.01196650 s | Counting: 0.05875350 s | RDX: 0.01001980 s
# n =   2364 | Random: 0.06693929 s | Median-of-Medians: 0.74434680 s | Three-way: 0.01153600 s | Counting: 0.05837610 s | RDX: 0.01171360 s
# n =   2477 | Random: 0.07121464 s | Median-of-Medians: 0.93754160 s | Three-way: 0.01245270 s | Counting: 0.05841250 s | RDX: 0.01066120 s
# n =   2595 | Random: 0.07736316 s | Median-of-Medians: 0.90783520 s | Three-way: 0.01232610 s | Counting: 0.05854690 s | RDX: 0.01139420 s
# n =   2718 | Random: 0.08293653 s | Median-of-Medians: 0.53131360 s | Three-way: 0.01190250 s | Counting: 0.06020310 s | RDX: 0.01070620 s
# n =   2848 | Random: 0.08917470 s | Median-of-Medians: 0.58143060 s | Three-way: 0.01251500 s | Counting: 0.05775640 s | RDX: 0.01036020 s
# n =   2983 | Random: 0.09776802 s | Median-of-Medians: 1.02374730 s | Three-way: 0.01159380 s | Counting: 0.05842200 s | RDX: 0.01010900 s
# n =   3125 | Random: 0.10640377 s | Median-of-Medians: 2.11833950 s | Three-way: 0.01168790 s | Counting: 0.05847980 s | RDX: 0.01055930 s
# n =   3274 | Random: 0.11358980 s | Median-of-Medians: 1.32340540 s | Three-way: 0.01162050 s | Counting: 0.05644060 s | RDX: 0.01047130 s
# n =   3430 | Random: 0.12331489 s | Median-of-Medians: 0.89798460 s | Three-way: 0.01013310 s | Counting: 0.05790110 s | RDX: 0.01069330 s
# n =   3593 | Random: 0.13228655 s | Median-of-Medians: 1.39996080 s | Three-way: 0.01092240 s | Counting: 0.05752710 s | RDX: 0.00988450 s
# n =   3764 | Random: 0.14514241 s | Median-of-Medians: 1.46560190 s | Three-way: 0.00959020 s | Counting: 0.05963280 s | RDX: 0.01049330 s
# n =   3944 | Random: 0.15874530 s | Median-of-Medians: 1.63982420 s | Three-way: 0.00920840 s | Counting: 0.05870930 s | RDX: 0.01134110 s
# n =   4132 | Random: 0.17298161 s | Median-of-Medians: 1.30261460 s | Three-way: 0.00974830 s | Counting: 0.05837540 s | RDX: 0.00999550 s
# n =   4328 | Random: 0.18830849 s | Median-of-Medians: 1.84801190 s | Three-way: 0.00834850 s | Counting: 0.05976250 s | RDX: 0.00992740 s
# n =   4534 | Random: 0.20580063 s | Median-of-Medians: 2.36517470 s | Three-way: 0.00771550 s | Counting: 0.05781150 s | RDX: 0.01045100 s
# n =   4750 | Random: 0.22267967 s | Median-of-Medians: 2.57479740 s | Three-way: 0.00755720 s | Counting: 0.05803390 s | RDX: 0.01062230 s
# n =   4977 | Random: 0.24485945 s | Median-of-Medians: 1.98046680 s | Three-way: 0.00769300 s | Counting: 0.05816370 s | RDX: 0.01029780 s
# n =   5214 | Random: 0.26858596 s | Median-of-Medians: 3.18874050 s | Three-way: 0.00828250 s | Counting: 0.05696390 s | RDX: 0.00999930 s
# n =   5462 | Random: 0.29397112 s | Median-of-Medians: 2.67440210 s | Three-way: 0.00749510 s | Counting: 0.05715820 s | RDX: 0.00981620 s
# n =   5722 | Random: 0.32280299 s | Median-of-Medians: 3.58579220 s | Three-way: 0.00625740 s | Counting: 0.05779680 s | RDX: 0.01104230 s
# n =   5994 | Random: 0.35215119 s | Median-of-Medians: 3.17000340 s | Three-way: 0.00591580 s | Counting: 0.05752420 s | RDX: 0.01006600 s
# n =   6280 | Random: 0.38587485 s | Median-of-Medians: 3.89482670 s | Three-way: 0.00578180 s | Counting: 0.05908170 s | RDX: 0.01037000 s
# n =   6579 | Random: 0.41723522 s | Median-of-Medians: 3.96488430 s | Three-way: 0.00554750 s | Counting: 0.05556700 s | RDX: 0.01031510 s
# n =   6892 | Random: 0.44778392 s | Median-of-Medians: 4.49461270 s | Three-way: 0.00463560 s | Counting: 0.05776370 s | RDX: 0.01050830 s
# n =   7220 | Random: 0.49326770 s | Median-of-Medians: 5.51241290 s | Three-way: 0.00400310 s | Counting: 0.05651120 s | RDX: 0.01012650 s
# n =   7564 | Random: 0.53823441 s | Median-of-Medians: 5.34012090 s | Three-way: 0.00361890 s | Counting: 0.05569170 s | RDX: 0.00959370 s
# n =   7924 | Random: 0.59078644 s | Median-of-Medians: 4.43757850 s | Three-way: 0.00322370 s | Counting: 0.05872980 s | RDX: 0.01057920 s
# n =   8302 | Random: 0.65529164 s | Median-of-Medians: 6.11461420 s | Three-way: 0.00270830 s | Counting: 0.05553950 s | RDX: 0.01085790 s
# n =   8697 | Random: 1.02630872 s | Median-of-Medians: 37.18579630 s | Three-way: 0.01237000 s | Counting: 0.32463370 s | RDX: 0.05734710 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import main
#       2 x=main.n_values
#       3 y=main.n_values1
#
# File c:\Users\K\Desktop\B\Algoritms-and-Data-Structure\Lab\main.py:69
#      66 arr = generate_repeated(arr_size,n,M)
#      68 rep_t_quick_random = main_measure(arr,iterative_quick_sort, Tmin,n,M)
# ---> 69 rep_t_quick_median = measure_time(arr,iterative_quick_sort_median, Tmin,n,M)
#      70 rep_t_quick_three = measure_time(arr,helper, Tmin,n,M)
#      71 rep_t_counting = measure_time(arr,counting_sort, Tmin,n,M)
#
# File c:\Users\K\Desktop\B\Algoritms-and-Data-Structure\Lab\measure.py:66, in measure_time(arr, sort_func, Tmin, n, m)
#      63 start_time = time.perf_counter()
#      64 while True:
#      65     #arr = generate_array(n,m)
# ---> 66     sort_func(arr.copy())  # Uso una copia per non modificare l'array originale
#      67     count += 1
#      68     elapsed = time.perf_counter() - start_time
#
# File c:\Users\K\Desktop\B\Algoritms-and-Data-Structure\Lab\Algorithms\quick_sort_iterative.py:55, in iterative_quick_sort_median(arr)
#      53 low, high = stack.pop()
#      54 if low < high:
# ---> 55     pivot = median_of_medians(arr[low:high + 1])
#      56     pivot_index = arr.index(pivot, low, high + 1)
#      57     swap(arr, pivot_index, high)
#
# File c:\Users\K\Desktop\B\Algoritms-and-Data-Structure\Lab\Algorithms\quick_sort_iterative.py:48, in iterative_quick_sort_median.<locals>.median_of_medians(arr)
#      46 if n <= 5:
#      47     return sorted(arr)[n // 2]
# ---> 48 medians = [sorted(arr[i:i+5])[len(arr[i:i+5]) // 2] for i in range(0, n, 5)]
#      49 return median_of_medians(medians)
#
# File c:\Users\K\Desktop\B\Algoritms-and-Data-Structure\Lab\Algorithms\quick_sort_iterative.py:48, in <listcomp>(.0)
#      46 if n <= 5:
#      47     return sorted(arr)[n // 2]
# ---> 48 medians = [sorted(arr[i:i+5])[len(arr[i:i+5]) // 2] for i in range(0, n, 5)]
#      49 return median_of_medians(medians)
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create sample data
'''x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)'''
plt.figure(figsize=(10, 5))  # Create the figure

# Plot 1 (First row, first column)
plt.subplot(1, 2, 1)  # (rows, columns, plot number)
plt.plot(x, main.times_quick_three, color='b', label='Quick3Way')
plt.ylim(global_min, global_max)
plt.title('QuickSort 3 way')
plt.legend()

# Plot 2 (First row, second column)
plt.subplot(1, 2, 2)
plt.plot(x, main.times_quick_random, color='r', linestyle='--', label='QuickNormal')
plt.ylim(global_min, global_max)
plt.title('Normal QuickSort')
plt.legend()

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Create sample data
'''x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)'''
plt.figure(figsize=(10, 5))  # Create the figure

# Plot 1 (First row, first column)
plt.subplot(1, 2, 1)  # (rows, columns, plot number)
plt.plot(x, main.times_counting, color='b', label='Counting')
plt.ylim(global_min, global_max)
plt.title('Counting Sort')
plt.legend()

# Plot 2 (First row, second column)
plt.subplot(1, 2, 2)
plt.plot(x, main.times_radix, color='r', linestyle='--', label='Radix')
plt.ylim(global_min, global_max)
plt.title('Radix Sort')
plt.legend()

plt.tight_layout()  # Adjust spacing to prevent overlap
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 8))  # 2x2 grid

# Top-left: Radix
plt.subplot(2, 2, 1)  # (rows, columns, plot number)
plt.plot(x, main.times_radix, color='b', label='Counting')
plt.ylim(global_min, global_max)
plt.title('Radix Sort')
plt.legend()

# Top-left: Counting
plt.subplot(2, 2, 2)  # (rows, columns, plot number)
plt.plot(x, main.times_counting, color='g', label='Counting')
plt.ylim(global_min, global_max)
plt.title('Counting Sort')
plt.legend()

# Top-left: QuickSort
plt.subplot(2, 2, 3)  # (rows, columns, plot number)
plt.plot(x, main.times_quick_random, color='r', label='Counting')
plt.ylim(global_min, global_max)
plt.title('Quick Sort')
plt.legend()

# Top-left: QuickSort3Way
plt.subplot(2, 2, 4)  # (rows, columns, plot number)
plt.plot(x, main.times_quick_three, color='black', label='Counting')
plt.ylim(global_min, global_max)
plt.title('Quick 3 way Sort')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.yscale("log")
x = np.linspace(0, 10, 100)
plt.plot(x, main.times_quick_three, label='QuickSort Three Way', color='blue')
plt.plot(x, main.times_quick_median, label='QuickSort Median of Medians', linestyle='--', color='orange')
plt.plot(x, main.times_quick_random, label='QuickSort Random Pivot', linestyle=':', color='green')
plt.plot(x, main.times_counting, label='CountingSort', linestyle='--', color='black')
plt.plot(x, main.times_radix, label='RadixSort', linestyle='-', color='red')

plt.title("Multiple Functions in One Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.ylim(-2, 2)  # Limit the y-axis
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\K\AppData\Local\Temp\ipykernel_12056\1714322283.py:15: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(-2, 2)  # Limit the y-axis

# %%
fig, ax = plt.subplots(2, 2, figsize=(10, 8))  # 2x2 grid

# Top-left: Radix
plt.subplot(2, 2, 1)  # (rows, columns, plot number)
plt.plot(y, main.rep_times_radix, color='b', label='Radix')
plt.ylim(global_min, global_max)
plt.title('Radix Sort')
plt.legend()

# Top-left: Counting
plt.subplot(2, 2, 2)  # (rows, columns, plot number)
plt.plot(y, main.rep_times_counting, color='g', label='Counting')
plt.ylim(global_min, global_max)
plt.title('Counting Sort')
plt.legend()

# Top-left: QuickSort
plt.subplot(2, 2, 3)  # (rows, columns, plot number)
plt.plot(y, y, color='r', label='Quick')
plt.ylim(global_min, global_max)
plt.title('Quick Sort')
plt.legend()

# Top-left: QuickSort3Way
plt.subplot(2, 2, 4)  # (rows, columns, plot number)
plt.plot(y, main.rep_times_quick_three, color='black', label='Quick3')
plt.ylim(global_min, global_max)
plt.title('Quick 3 way Sort')
plt.legend()

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.yscale("log")
x = np.linspace(0, 10, 100)
plt.plot(x, main.rep_times_quick_three, label='QuickSort Three Way', color='blue')
plt.plot(x, main.rep_times_quick_median, label='QuickSort Median of Medians', linestyle='--', color='orange')
plt.plot(x, main.rep_times_quick_random, label='QuickSort Random Pivot', linestyle=':', color='green')
plt.plot(x, main.rep_times_counting, label='CountingSort', linestyle='--', color='black')
plt.plot(x, main.rep_times_radix, label='RadixSort', linestyle='-', color='red')

plt.title("Multiple Functions in One Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.ylim(-2, 2)  # Limit the y-axis
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\K\AppData\Local\Temp\ipykernel_12056\2559022475.py:15: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(-2, 2)  # Limit the y-axis
